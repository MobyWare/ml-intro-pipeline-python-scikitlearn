# %% [markdown]
# # Goal
#
# Learn about scikit learn piplelines, clustering and visualizatiions using ggplot.
#
#
# I plan to use some wine dat from ref 2 and housing data.
#
# # References
# 1. [ggplot for python](http://blog.yhat.com/posts/ggplot-for-python.html)
# 2. [About feature scaling and normalization](http://sebastianraschka.com/Articles/2014_about_feature_scaling.html)

# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt

# %%
wines = pd.read_csv('wine.csv')
wines.columns = ['class', 'alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 
                'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 
                'color_intensity', 'hue', 'diluted_wines_metric', 'proline']

# %%
wines.head()
# Out:
#    class  alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  \
# 0      1    13.20        1.78  2.14               11.2        100
# 1      1    13.16        2.36  2.67               18.6        101
# 2      1    14.37        1.95  2.50               16.8        113
# 3      1    13.24        2.59  2.87               21.0        118
# 4      1    14.20        1.76  2.45               15.2        112
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    color_intensity   hue  diluted_wines_metric  proline
# 0             4.38  1.05                  3.40     1050
# ...

# %% [markdown]
# ## Data Exploration
#
# ### Conclusions
# Looking at the summary of each column the devation vs mean stands out. As a for instance:
# * Color intensity looks promising,especially from the visualization.

# %%
wines.describe()
# Out:
#             class     alcohol  malic_acid         ash  alcalinity_of_ash  \
# count  177.000000  177.000000  177.000000  177.000000         177.000000
# mean     1.943503   12.993672    2.339887    2.366158          19.516949
# std      0.773991    0.808808    1.119314    0.275080           3.336071
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.360000    1.600000    2.210000          17.200000
# 50%      2.000000   13.050000    1.870000    2.360000          19.500000
# 75%      3.000000   13.670000    3.100000    2.560000          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         magnesium  total_phenols  flavanoids  nonflavanoid_phenols  \
# count  177.000000     177.000000  177.000000            177.000000
# mean    99.587571       2.292260    2.023446              0.362316
# std     14.174018       0.626465    0.998658              0.124653
# ...

# %%
plt.figure(figsize=(16,12))
wines[['color_intensity', 'class']].boxplot(by='class')
plt.show()

# %%
#plt.figure(figsize=(16,12))
fig_alcohol = plt.figure(2, figsize=(8,6))
ax_alcohol = fig_alcohol.add_subplot(222)
bp_alcohol = ax_alcohol.boxplot(wines[['alcohol', 'class']])
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-25-a72b83baa740> in <module>()
#       2 fig_alcohol = plt.figure(2, figsize=(8,6))
#       3 ax_alcohol = fig_alcohol.add_subplot(222)
# ----> 4 bp_alcohol = ax_alcohol.boxplot(wines[['alcohol', 'class']])
#
# C:\Users\dickm\AppData\Local\Continuum\Anaconda2\lib\site-packages\matplotlib\__init__.pyc in inner(ax, *args, **kwargs)
#    1809                     warnings.warn(msg % (label_namer, func.__name__),
#    1810                                   RuntimeWarning, stacklevel=2)
# -> 1811             return func(ax, *args, **kwargs)
#    1812         pre_doc = inner.__doc__
#    1813         if pre_doc is None:
#
# ...
